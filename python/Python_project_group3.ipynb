# %% [markdown]
# # University of Niagara Falls
# ## Master of Science in Data Analytics
#
# ---
#
# # **CREDIT DEFAULT RISK ANALYSIS REPORT**
# ### A Machine Learning Classification Study
#
# ---
#
# ### **Course Name:**
# CPSC‑610: Python for Data Analysis
#
# ### **Instructor:**
# Dr. Mohannad Al Mousa
#
# ### **Date of Submission:**
# June 14, 2026
#
# ### **Student Team:**
# 1. Manpreet Kaur
# 2. Nicolas Ricardo Ysa Pelaez
# 3. Daniela Montilla Fernandez
# 4. Jose Alberto Martinez Morales
# 5. Sravani Maguluru
#
# ---

# %% [markdown]
# # 1. Project Overview
#
# This project examines credit default risk using two complementary datasets: a loan applications dataset used for predictive modeling, and a credit inquiries dataset used for business insights. Together, these datasets provide a comprehensive view of borrower behavior, credit demand, and repayment outcomes.
#
# ---
#
# ## Applications Dataset. Used for Predictive Modeling
#
# Each row in the applications dataset represents a completed loan application with detailed borrower, loan, and credit profile information.
# The dataset includes the following key fields:
#
# - application_id — Unique identifier for each loan application
# - requested_amount_usd — Loan amount requested
# - repayment_term_text — Repayment duration as text
# - interest_rate_text — Interest rate as text
# - monthly_installment_usd — Scheduled monthly payment
# - last_payment_amount_usd — Most recent payment amount
# - risk_grade_band and risk_grade_detail — Credit risk categories
# - employment_tenure_text — Borrower employment length
# - housing_status — Housing situation
# - annual_income_usd — Reported annual income
# - income_verification_status — Verification category
# - origination_month — Month the loan originated
# - outcome_status — Final loan outcome
# - loan_purpose — Borrower-stated purpose
# - region_code — Geographic region
# - debt_to_income_ratio — Borrower DTI
# - credit_score_low and credit_score_high — Credit score range
# - open_credit_lines — Number of open accounts
# - public_records_count — Number of derogatory public records
# - revolving_utilization_text — Revolving credit utilization
#
# Because this dataset contains the final loan outcome, it is used to build the predictive model.
#
# ---
#
# ## Prediction Target
#
# The goal of the predictive component is to determine whether a loan application results in default.
# The target variable is defined as:
#
# - target_default = 1 if outcome_status == "Charged Off"
# - target_default = 0 otherwise
#
# This converts the problem into a binary classification task suitable for machine learning.
#
# ---
#
# ## Inquiries Dataset. Used for Business Insights
#
# The inquiries dataset contains information about credit inquiries submitted by potential borrowers.
# It includes the following fields:
#
# - requested_amount_usd — Amount requested during inquiry
# - application_date — Date of inquiry
# - request_title — Free-text description of the request
# - screening_score — Preliminary risk score
# - debt_to_income_text — DTI expressed as text
# - region_code — Geographic region
# - employment_tenure_text — Employment length
# - policy_code — Policy indicator
#
# This dataset does not contain loan outcomes and therefore cannot be used for supervised learning.
# Instead, it supports business insights by revealing patterns in borrower demand, screening score distributions, regional inquiry trends, and employment characteristics at inquiry time.
#
# ---
#
# ## Model Evaluation Approach
#
#
# The model will be evaluated using three complementary methods:
#
# 1. **Confusion Matrix**
#    Used to understand the distribution of correct and incorrect predictions.
#
# 2. **A false-positive–focused metric**
#    This directly supports the business objective of minimizing cases where the model incorrectly predicts that a borrower will repay when they actually default.
#
# 3. **ROC–AUC Curve**
#    Used to assess overall model discrimination and to help analyze potential overfitting or underfitting.
#
# ---
#
# ## Project Workflow
#
# The analysis follows a complete data science pipeline:
#
# ### 1. Data Cleaning
# Both datasets are cleaned thoroughly by:
# - Handling missing values
# - Removing duplicates
# - Converting text fields to numeric
# - Standardizing categorical values
# - Detecting and treating outliers
# - Removing leakage variables
# - Ensuring correct data types
#
# ### 2. Exploratory Data Analysis (EDA)
# EDA is performed separately on each dataset to uncover:
# - Distribution of key variables
# - Relationships between borrower characteristics and default risk
# - Regional and behavioral patterns in inquiry activity
# - Correlations among financial indicators
#
# ### 3. Feature Engineering
# The applications dataset is transformed into a modeling-ready format through:
# - Creation of numeric features (for example, employment tenure, repayment term)
# - Cleaning and scaling of financial variables
# - Encoding of categorical variables
# - Removal of leakage and post-outcome fields
#
# ### 4. Model Building
# At least two classification models are developed:
# - Logistic Regression (baseline)
# - Random Forest (non-linear model)
#
# Models are trained using a stratified train/test split and a preprocessing pipeline.
#
# ### 5. Model Evaluation
# Models are evaluated using:
# - Confusion matrix
# - A false-positive–focused metric aligned with the business objective
# - ROC–AUC curve to assess model separation and diagnose overfitting or underfitting
#
# ### 6. Business Insights
# Insights are drawn from both datasets to answer questions such as:
# - Which borrower characteristics are most associated with default?
# - Which loan purposes or regions exhibit higher risk?
# - What patterns emerge in inquiry behavior?
# - How can lenders adjust policies or thresholds to reduce losses?
#
# ### 7. Conclusion and Recommendations
# The project concludes with:
# - A summary of findings
# - The recommended model
# - Actionable business recommendations
# - Limitations and opportunities for future work
#
# ---
#
# ## Purpose and Relevance
#
# Credit default prediction is essential for effective risk management.
# Accurate models help lenders:
# - Reduce financial losses
# - Improve approval decisions
# - Identify high-risk borrower segments
# - Support pricing and policy strategies
#
# By combining predictive modeling with inquiry-level insights, this project provides a comprehensive framework for understanding and managing credit risk.

# %% [markdown]
# # 2. Data Cleaning
#
# This section prepares both datasets for analysis by identifying and resolving issues related to missing values, duplicates, incorrect data types, inconsistent formatting, and outliers.
# The cleaning process is divided into two parts:
#
# - **2A. Applications Dataset (Prediction Dataset)**
# - **2B. Inquiries Dataset (Business Insights Dataset)**
#
# Each subsection includes diagnostics, visualizations, and documented decisions.
#
# ---
#
# # 2A. Data Cleaning — Applications Dataset (Prediction Dataset)
#
# The applications dataset contains borrower, loan, and credit profile information.
# Because this dataset is used for predictive modeling, it must be cleaned thoroughly to avoid data leakage, incorrect model behavior, or biased results.
#
# ---
#
# ## 2A.1 Initial Structure and Diagnostics
#
# We begin by inspecting the dataset structure, data types, missing values, and duplicates.

# %%
import pandas as pd
import numpy as np
apps = pd.read_csv('../data/creditrisk_applications_final.csv')
apps.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 85000 entries, 0 to 84999
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   application_id              85000 non-null  int64
#  1   requested_amount_usd        85000 non-null  float64
#  2   repayment_term_text         85000 non-null  str
#  3   interest_rate_text          85000 non-null  float64
#  4   monthly_installment_usd     85000 non-null  float64
#  5   last_payment_amount_usd     85000 non-null  float64
#  6   risk_grade_band             85000 non-null  str
#  7   risk_grade_detail           85000 non-null  str
#  8   employment_tenure_text      76324 non-null  str
#  9   housing_status              85000 non-null  str
#  10  annual_income_usd           84320 non-null  float64
#  11  income_verification_status  85000 non-null  str
#  12  origination_month           85000 non-null  str
#  13  outcome_status              85000 non-null  str
#  14  loan_purpose                85000 non-null  str
#  15  region_code                 85000 non-null  str
#  16  debt_to_income_ratio        84291 non-null  str
#  17  credit_score_low            85000 non-null  float64
#  18  credit_score_high           85000 non-null  float64
#  19  open_credit_lines           85000 non-null  float64
#  20  public_records_count        85000 non-null  float64
#  21  revolving_utilization_text  84108 non-null  float64
# dtypes: float64(10), int64(1), str(11)
# memory usage: 14.3 MB

# %%
# Checking null values 
apps.isna().sum().sort_values(ascending=False)
# Out:
# employment_tenure_text        8676
# revolving_utilization_text     892
# debt_to_income_ratio           709
# annual_income_usd              680
# application_id                   0
# requested_amount_usd             0
# last_payment_amount_usd          0
# monthly_installment_usd          0
# interest_rate_text               0
# repayment_term_text              0
# housing_status                   0
# income_verification_status       0
# risk_grade_detail                0
# risk_grade_band                  0
# outcome_status                   0
# origination_month                0
# region_code                      0
# loan_purpose                     0
# credit_score_low                 0
# credit_score_high                0
# open_credit_lines                0
# public_records_count             0
# dtype: int64

# %%
# Checking duplicates
apps.duplicated('application_id').sum()
# Out:
# np.int64(0)

# %%
apps.shape
# Out:
# (85000, 22)

# %% [markdown]
# ### **Insight  Data Quality and Missingness Patterns**
#
# The applications dataset is generally well‑structured, with **85,000 rows** and **22 columns**, and no duplicate `application_id` values.
# However, several fields contain meaningful missingness that must be addressed before modeling:
#
# - **employment_tenure_text** has the highest missingness (**8,676 records**).
#   This suggests inconsistent reporting of employment history, which may reflect borrower instability or data collection gaps.
#
# - **revolving_utilization_text**, **debt_to_income_ratio**, and **annual_income_usd** each have **600–900 missing values**.
#   These are financially important variables, so missingness must be handled carefully to avoid bias.
#
# - All other fields are fully populated, including key credit indicators such as
#   `credit_score_low`, `credit_score_high`, `open_credit_lines`, and `public_records_count`.
#
# - No duplicate applications were found, confirming dataset integrity.
#
# **Interpretation:**
# The missingness is concentrated in employment and financial capacity variables, which are often correlated with borrower risk.
# This pattern suggests that borrowers with incomplete financial information may represent a distinct risk segment, and imputation strategies must be chosen carefully to avoid introducing bias.

# %% [markdown]
# ## 2A.2 Duplicate Removal

# %%
# Checking for duplicates
apps = apps.drop_duplicates(subset='application_id')

# %% [markdown]
# ### **Insight Duplicate Check on `application_id`**
#
# The result shows:
#
# - **0 duplicate rows**
# - **All 85,000 application IDs are unique**
#
# **Interpretation:**
# The applications dataset has strong structural integrity.
# Since each `application_id` appears exactly once, we can confidently treat each row as a unique loan application without needing to remove or consolidate duplicate entries.
# This ensures that the modeling dataset is not biased by repeated records and that each borrower’s application contributes equally to the analysis.

# %% [markdown]
# ## 2A.3 Numeric and Categorical Diagnostics Before Cleaning
#
# Before converting any fields, we first examine the dataset by separating **numeric** and **categorical** columns.
# This allows us to verify whether each variable has the correct datatype and identify fields that require transformation.
#
# ---
#
# ### **2A.3.1 Summary Statistics — Numeric Columns**

# %%
# Describe in numerical variables 
apps.select_dtypes(include=['int64', 'float64']).describe()
# Out:
#        application_id  requested_amount_usd  interest_rate_text  \
# count    8.500000e+04          85000.000000        85000.000000
# mean     6.633685e+07          14950.852647           13.600630
# std      2.482399e+07           8735.147461            4.886372
# min      3.476740e+05           1000.000000            5.310000
# 25%      4.881616e+07           8000.000000            9.990000
# 50%      6.059760e+07          13050.000000           13.180000
# 75%      7.635120e+07          20000.000000           16.550000
# max      1.411120e+08          40000.000000           30.990000
#
#        monthly_installment_usd  last_payment_amount_usd  annual_income_usd  \
# count             85000.000000             85000.000000       8.432000e+04
# mean                446.071413              3604.090989       7.434189e+04
# std                 258.523612              6222.901104       7.732271e+04
# min                  30.120000                 0.000000       0.000000e+00
# 25%                 259.955000               308.220000       4.500000e+04
# 50%                 382.870000               598.895000       6.300000e+04
# 75%                 587.690000              4130.377500       9.000000e+04
# max                1587.230000             40551.270000       8.900060e+06
#
#        credit_score_low  credit_score_high  open_credit_lines  \
# count      85000.000000       85000.000000       85000.000000
# mean         692.034412         696.034482          11.920871
# std           29.787475          29.787839           5.670095
# min          660.000000         664.000000           1.000000
# 25%          670.000000         674.000000           8.000000
# 50%          685.000000         689.000000          11.000000
# 75%          705.000000         709.000000          15.000000
# max          845.000000         850.000000          70.000000
#
#        public_records_count  revolving_utilization_text
# count          85000.000000                84108.000000
# mean               0.248718                   52.342891
# std                0.656437                   24.293508
# min                0.000000                    0.000000
# 25%                0.000000                   34.200000
# 50%                0.000000                   52.800000
# 75%                0.000000                   70.900000
# max               49.000000                  136.400000

# %% [markdown]
# ### **Insight Numeric Variable Summary**
#
# The summary statistics for all numeric columns reveal that the dataset is generally well‑structured, with reasonable ranges and no obvious data corruption in the core financial and credit variables.
#
# Key observations:
#
# - **Loan amounts and payments** (`requested_amount_usd`, `monthly_installment_usd`, `last_payment_amount_usd`) show realistic ranges with no negative values, confirming correct numeric formatting.
#
# - **Credit score fields** (`credit_score_low`, `credit_score_high`) fall within expected credit score boundaries (typically 300–850), indicating clean and valid values.
#
# - **Open credit lines and public records** contain non‑negative integers, as expected for count variables.
#
# - **Interest rate** and **revolving utilization** are stored as numeric values but represent **percentages**, meaning they must be converted to decimals before modeling.
#
# - **Annual income** shows a wide but reasonable distribution, with no extreme outliers that would indicate data corruption.
#
# **Interpretation:**
# The numeric fields are structurally sound and correctly typed.
# The only required transformation is converting percentage‑based numeric fields (interest rate and revolving utilization) into decimal form.
# No numeric variable appears to be misclassified as categorical, and no categorical variable appears to be incorrectly stored as numeric.

# %% [markdown]
# ### **2A.3.2 Summary Statistics — Categorical Columns**

# %%
apps.select_dtypes(include=['object', 'string']).describe()
# Out:
#        repayment_term_text risk_grade_band risk_grade_detail  \
# count                85000           85000             85000
# unique                   2               7                35
# top              36 months               C                C4
# freq                 59223           25111              5289
#
#        employment_tenure_text housing_status income_verification_status  \
# count                   76324          85000                      85000
# unique                     11              7                          3
# top                 10+ years       MORTGAGE            Source Verified
# freq                    26275          38111                      36936
#
#        origination_month outcome_status        loan_purpose region_code  \
# count              85000          85000               85000       85000
# unique                23              2                  24         100
# top             Jul-2015     Fully Paid  debt_consolidation          CA
# freq                6989          42500               49344       11601
#
#        debt_to_income_ratio
# count                 84291
# unique                 4391
# top                     bad
# freq                    336

# %% [markdown]
# ### **Insight Categorical Variable Summary**
#
# The categorical summary reveals that the dataset contains a diverse set of borrower, loan, and credit‑related categories.
# Most categorical fields appear structurally sound, but several require standardization or datatype correction.
#
# Key observations:
#
# - **repayment_term_text** contains only two categories (“36 months” and “60 months”), confirming it should be treated as a **categorical variable**, not numeric.
#   Minor formatting inconsistencies (capitalization, spacing) may require standardization.
#
# - **employment_tenure_text** shows a wide range of employment duration labels (e.g., “10+ years”, “< 1 year”, “3 years”).
#   These represent **ordered categories**, not numeric values, and must be cleaned for consistency.
#
# - **debt_to_income_ratio** is stored as **mixed text**, containing:
#   - numeric strings (“18”, “24”, “14.88”)
#   - corrupted values (“bad”)
#   - thousands of unique text entries
#   This confirms the column is incorrectly typed and must be cleaned and converted to numeric.
#
# - **risk_grade_band**, **risk_grade_detail**, **housing_status**, **loan_purpose**, and **region_code** show clean, well‑defined category sets with no obvious anomalies.
#
# - **origination_month** is stored as text but represents a **date‑like categorical variable**.
#   It may be useful to convert this into a proper datetime or extract month/quarter features during feature engineering.
#
# **Interpretation:**
# The categorical fields are generally well‑structured, but several require cleaning or standardization.
# The most significant issue is the `debt_to_income_ratio` column, which must be converted from mixed text to numeric.
# Repayment term and employment tenure should remain categorical but need consistent formatting.

# %% [markdown]
# ## 2A.4 Cleaning Based on Diagnostics for Numerical Variables
#
# This section applies the cleaning rules derived from the numerical diagnostics and prepares the dataset for modeling. The following steps were performed:
#
# ---
#
# ### 1. Remove application_id (non-predictive identifier)
#
# The variable application_id is a unique identifier with no predictive value.
# It is removed from the dataset:

# %%
# Removing the application id
apps.drop(columns=['application_id'], inplace=True)

# %% [markdown]
# ### 2. Convert all _text numeric fields into proper numeric variables
# Several numeric variables were originally stored as text and ended with the suffix _text.
# For each of these variables:
#
# Remove the _text suffix
# Convert the cleaned column to numeric
# Add the new numeric column to the dataset
# Drop the original _text column
#
# Variables cleaned:
#
# interest_rate_text → interest_rate
# revolving_utilization_text → revolving_utilization
#
# Code used:

# %%
# Only numeric _text columns
numeric_text_cols = [
    'interest_rate_text',
    'revolving_utilization_text'
]

for col in numeric_text_cols:
    new_col = col.replace('_text', '')
    apps[new_col] = pd.to_numeric(apps[col], errors='coerce')
    apps.drop(columns=[col], inplace=True)

# %%
apps.select_dtypes(include=['int64', 'float64']).describe()
# Out:
#        requested_amount_usd  monthly_installment_usd  last_payment_amount_usd  \
# count          85000.000000             85000.000000             85000.000000
# mean           14950.852647               446.071413              3604.090989
# std             8735.147461               258.523612              6222.901104
# min             1000.000000                30.120000                 0.000000
# 25%             8000.000000               259.955000               308.220000
# 50%            13050.000000               382.870000               598.895000
# 75%            20000.000000               587.690000              4130.377500
# max            40000.000000              1587.230000             40551.270000
#
#        annual_income_usd  credit_score_low  credit_score_high  \
# count       8.432000e+04      85000.000000       85000.000000
# mean        7.434189e+04        692.034412         696.034482
# std         7.732271e+04         29.787475          29.787839
# min         0.000000e+00        660.000000         664.000000
# 25%         4.500000e+04        670.000000         674.000000
# 50%         6.300000e+04        685.000000         689.000000
# 75%         9.000000e+04        705.000000         709.000000
# max         8.900060e+06        845.000000         850.000000
#
#        open_credit_lines  public_records_count  interest_rate  \
# count       85000.000000          85000.000000   85000.000000
# mean           11.920871              0.248718      13.600630
# std             5.670095              0.656437       4.886372
# min             1.000000              0.000000       5.310000
# 25%             8.000000              0.000000       9.990000
# 50%            11.000000              0.000000      13.180000
# 75%            15.000000              0.000000      16.550000
# max            70.000000             49.000000      30.990000
#
#        revolving_utilization
# count           84108.000000
# mean               52.342891
# std                24.293508
# min                 0.000000
# 25%                34.200000
# 50%                52.800000
# 75%                70.900000
# max               136.400000

# %%
# Ensure full output (prevents truncation in Jupyter)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# Select ONLY string + categorical columns (future-proof)
cat_cols = apps.select_dtypes(include=['string', 'category']).columns

# Loop through each categorical variable and print value counts
for col in cat_cols:
    print(f"\n===== {col} =====")
    print(apps[col].value_counts(dropna=False))
# Out:
# ===== repayment_term_text =====
# repayment_term_text
# 36 months    59223
# 60 months    25777
# Name: count, dtype: int64
#
# ===== risk_grade_band =====
# risk_grade_band
# C    25111
# B    21169
# D    14775
# A    11946
# E     8311
# F     2741
# G      947
# Name: count, dtype: int64
#
# ===== risk_grade_detail =====
# risk_grade_detail
# C4    5289
# C1    5139
# C3    5051
# C2    5036
# B5    4708
# B4    4602
# C5    4596
# B3    4342
# B1    3795
# B2    3722
# D1    3616
# A5    3505
# D2    3122
# D3    2821
# D4    2791
# A4    2719
# D5    2425
# A1    2100
# E1    1996
# E2    1922
# A3    1819
# A2    1803
# E3    1697
# E4    1380
# E5    1316
# F1     836
# F2     639
# F3     513
# F4     413
# F5     340
# G1     269
# G2     215
# G3     176
# G4     160
# G5     127
# Name: count, dtype: int64
#
# ===== employment_tenure_text =====
# employment_tenure_text
# 10+ years    26275
# NaN           8676
# 2 years       7260
# < 1 year      6985
# 3 years       6647
# 1 year        5590
# 4 years       4964
# 5 years       4921
# 8 years       3912
# 7 years       3380
# 6 years       3257
# 9 years       3133
# Name: count, dtype: int64
#
# ===== housing_status =====
# housing_status
# MORTGAGE    38111
# RENT        35338
# OWN          9425
# mortgage     1007
# rent          879
# own           239
# ANY             1
# Name: count, dtype: int64
#
# ===== income_verification_status =====
# income_verification_status
# Source Verified    36936
# Verified           26603
# Not Verified       21461
# Name: count, dtype: int64
#
# ===== origination_month =====
# origination_month
# Jul-2015    6989
# Oct-2015    6831
# Dec-2015    6400
# Nov-2015    5408
# Jan-2015    5338
# Apr-2015    5328
# Aug-2015    5216
# May-2015    4828
# Apr-2016    4281
# Sep-2015    4192
# Jun-2015    4173
# Mar-2015    3787
# Jun-2016    3591
# Feb-2015    3459
# May-2016    3353
# Aug-2017    2737
# Jul-2017    2569
# Sep-2017    2382
# Jan-2018    1443
# Mar-2018    1169
# Feb-2018    1122
# Sep-2018     283
# Aug-2018     121
# Name: count, dtype: int64
#
# ===== outcome_status =====
# outcome_status
# Fully Paid     42500
# Charged Off    42500
# Name: count, dtype: int64
#
# ===== loan_purpose =====
# loan_purpose
# debt_consolidation     49344
# credit_card            17562
# home_improvement        5133
# other                   4684
# major_purchase          1635
# debt_consolidation      1547
# medical                  932
# small_business           836
# car                      718
# moving                   623
# vacation                 531
# credit_card              523
# house                    400
# home_improvement         159
# other                    150
# renewable_energy          52
# major_purchase            46
# medical                   34
# car                       31
# vacation                  22
# small_business            15
# moving                    13
# house                      8
# renewable_energy           2
# Name: count, dtype: int64
#
# ===== region_code =====
# region_code
# CA      11601
# NY       7129
# TX       6775
# FL       6027
# IL       3141
# NJ       3047
# PA       2841
# OH       2799
# GA       2612
# NC       2361
# MI       2324
# VA       2239
# AZ       2031
# MD       2012
# MA       1819
# CO       1707
# WA       1660
# MN       1511
# IN       1465
# TN       1361
# MO       1328
# NV       1281
# WI       1155
# CT       1139
# AL       1116
# LA       1034
# SC        934
# OR        847
# OK        837
# KY        825
# AR        635
# KS        633
# UT        593
# MS        539
# NM        518
# HI        435
# RI        364
# NH        362
# NE        314
# WV        306
# DE        242
#  CA       241
# MT        225
# SD        197
# AK        177
# DC        173
# WY        159
#  TX       158
#  NY       146
# ME        133
# VT        129
# ND        117
#  FL       109
# ID         91
#  PA        65
#  IL        64
#  OH        63
#  GA        61
#  NC        59
#  NJ        58
#  AZ        49
#  VA        45
#  MD        43
#  MI        43
#  CO        40
#  IN        30
#  WA        30
#  NV        30
#  MN        28
#  CT        27
#  OK        24
#  TN        23
#  MA        22
#  WI        22
#  AL        21
#  OR        19
#  MO        18
#  LA        16
#  UT        14
#  KS        13
#  MS        12
#  SC        12
#  RI        12
#  NM         9
#  HI         8
#  AR         7
#  NH         7
#  WV         7
#  KY         6
#  AK         6
#  WY         6
#  ND         5
#  NE         4
#  DC         4
#  DE         4
#  VT         3
#  SD         2
#  ID         2
#  MT         2
#  ME         1
# Name: count, dtype: int64
#
# ===== debt_to_income_ratio =====
# debt_to_income_ratio
# NaN       709
# bad       336
# 18.0       62
# 24.0       59
# 12.0       57
# 14.88      55
# 16.4       55
# 14.4       55
# 10.8       54
# 22.0       54
# 12.8       54
# 16.32      54
# 17.46      53
# 22.8       53
# 18.96      51
# 15.14      51
# 18.72      51
# 15.67      50
# 16.8       50
# 26.4       49
# 16.38      49
# 19.2       49
# 18.03      49
# 16.58      49
# 17.76      48
# 13.68      48
# 16.86      48
# 13.92      48
# 19.34      48
# 15.6       47
# 23.4       47
# 20.4       47
# 13.2       47
# 12.15      47
# 15.64      47
# 15.68      47
# 14.92      47
# 17.18      47
# 14.16      46
# 17.56      46
# 18.48      46
# 22.53      46
# 18.55      46
# 19.39      46
# 16.08      46
# 20.82      46
# 16.13      46
# 18.67      46
# 13.48      46
# 18.76      45
# 14.49      45
# 14.93      45
# 17.68      45
# 22.29      45
# 20.88      45
# 15.95      45
# 16.23      45
# 15.07      45
# 18.6       44
# 26.37      44
# 14.98      44
# 13.75      44
# 16.43      44
# 12.46      44
# 16.83      44
# 16.62      44
# 15.72      44
# 16.45      44
# 13.0       44
# 17.04      44
# 13.57      44
# 21.33      44
# 14.5       44
# 21.6       43
# 16.56      43
# 20.09      43
# 19.07      43
# 19.56      43
# 17.22      43
# 18.65      43
# 15.47      43
# 18.24      43
# 16.2       43
# 16.84      43
# 21.54      43
# 16.26      43
# 17.28      43
# 18.12      43
# 14.2       43
# 17.08      43
# 14.13      43
# 21.8       43
# 13.5       43
# 12.24      43
# 17.73      43
# 12.08      43
# 17.38      42
# 14.29      42
# 17.44      42
# 14.33      42
# 17.52      42
# 17.92      42
# 21.76      42
# 19.26      42
# 18.04      42
# 19.52      42
# 16.89      42
# 12.34      42
# 19.09      42
# 21.88      42
# 20.79      42
# 17.4       42
# 21.17      42
# 18.74      42
# 21.92      42
# 23.25      42
# 20.38      42
# 18.43      41
# 20.21      41
# 21.36      41
# 16.55      41
# 20.74      41
# 13.82      41
# 21.32      41
# 12.6       41
# 18.94      41
# 19.82      41
# 16.02      41
# 22.12      41
# 19.77      41
# 19.36      41
# 11.47      41
# 15.3       41
# 16.03      41
# 12.93      41
# 14.76      41
# 22.28      41
# 22.08      41
# 19.65      41
# 14.12      41
# 9.6        41
# 13.15      41
# 18.34      41
# 24.9       41
# 16.66      41
# 13.56      41
# 22.5       41
# 20.16      40
# 16.97      40
# 13.55      40
# 18.52      40
# 21.2       40
# 16.16      40
# 25.92      40
# 21.16      40
# 22.87      40
# 21.15      40
# 14.86      40
# 15.84      40
# 13.7       40
# 26.13      40
# 18.81      40
# 21.0       40
# 16.76      40
# 19.68      40
# 11.94      40
# 25.75      40
# 16.0       40
# 22.93      40
# 10.32      40
# 19.66      40
# 24.65      40
# 16.52      40
# 18.84      40
# 12.97      40
# 19.5       40
# 18.69      40
# 19.95      40
# 18.83      40
# 14.32      40
# 20.26      40
# 13.42      40
# 24.8       40
# 16.9       40
# 24.34      40
# 25.18      40
# 24.96      40
# 17.49      40
# 16.36      40
# 17.5       39
# 16.12      39
# 20.62      39
# 21.81      39
# 15.75      39
# 16.42      39
# 17.34      39
# 22.6       39
# 17.83      39
# 14.97      39
# 20.0       39
# 13.89      39
# 16.61      39
# 18.37      39
# 19.48      39
# 20.73      39
# 20.56      39
# 19.87      39
# 14.27      39
# 14.95      39
# 16.74      39
# 19.63      39
# 17.11      39
# 21.12      39
# 13.63      39
# 13.94      39
# 17.64      39
# 16.35      39
# 14.62      39
# 12.67      39
# 21.25      39
# 22.69      39
# 17.3       39
# 22.4       39
# 17.1       39
# 16.98      39
# 21.7       39
# 17.03      39
# 13.29      39
# 21.21      39
# 18.8       39
# 19.6       39
# 19.16      39
# 17.24      39
# 10.35      39
# 23.72      39
# 20.71      39
# 20.68      39
# 16.92      39
# 13.91      39
# 21.73      39
# 13.88      39
# 14.64      39
# 16.75      39
# 21.23      39
# 21.47      39
# 10.14      39
# 24.23      39
# 11.28      38
# 15.36      38
# 13.31      38
# 11.96      38
# 22.59      38
# 20.25      38
# 8.4        38
# 24.24      38
# 19.38      38
# 25.06      38
# 18.18      38
# 21.53      38
# 15.9       38
# 18.98      38
# 19.88      38
# 25.08      38
# 19.42      38
# 14.35      38
# 17.16      38
# 11.11      38
# 18.02      38
# 15.53      38
# 14.61      38
# 13.39      38
# 16.44      38
# 23.28      38
# 21.06      38
# 26.9       31
# 14.66      31
# 23.67      31
# 25.8       31
# 13.87      31
# 28.4       31
# 12.65      31
# 14.06      31
# 21.13      31
# 20.3       31
# 14.02      31
# 26.28      31
# 13.8       31
# 23.45      31
# 21.96      31
# 25.97      31
# 20.57      31
# 22.77      31
# 12.59      31
# 21.1       31
# 14.81      31
# 25.02      31
# 17.57      31
# 17.86      31
# 22.25      31
# 29.4       31
# 18.45      31
# 27.44      31
# 14.05      31
# 24.69      31
# 12.73      31
# 17.35      31
# 12.31      31
# 22.48      31
# 12.27      31
# 11.04      31
# 9.42       31
# 12.03      31
# 13.96      31
# 7.57       31
# 15.11      31
# 16.57      31
# 30.9       31
# 22.27      31
# 22.34      31
# 26.46      31
# 22.78      31
# 20.95      31
# 13.08      31
# 17.07      31
# 30.87      31
# 24.72      31
# 14.94      31
# 22.91      31
# 11.95      31
# 13.52      31
# 24.62      31
# 13.02      31
# 17.9       31
# 15.7       31
# 11.58      31
# 27.69      31
# 16.3       30
# 11.37      30
# 13.13      30
# 29.43      30
# 17.43      30
# 20.67      30
# 25.11      30
# 13.67      30
# 10.29      30
# 15.69      30
# 15.35      30
# 11.48      30
# 11.07      30
# 10.53      30
# 23.38      30
# 23.02      30
# 27.32      30
# 11.13      30
# 26.44      30
# 12.77      30
# 22.46      30
# 11.72      30
# 22.38      30
# 23.91      30
# 18.32      30
# 16.93      30
# 23.35      30
# 17.71      30
# 10.6       30
# 23.87      30
# 22.98      30
# 22.26      30
# 21.65      30
# 22.04      30
# 19.27      30
# 25.49      30
# 28.08      30
# 29.23      30
# 20.31      30
# 19.45      30
# 10.31      30
# 22.22      30
# 22.43      30
# 18.23      30
# 21.56      30
# 26.6       30
# 15.04      30
# 16.48      30
# 20.28      30
# 20.02      30
# 12.11      30
# 23.97      30
# 17.59      30
# 12.69      30
# 25.09      30
# 25.55      30
# 24.7       30
# 10.02      30
# 20.94      30
# 11.31      30
# 25.25      30
# 19.24      30
# 26.04      30
# 12.7       30
# 12.79      30
# 9.48       30
# 16.18      30
# 21.9       30
# 24.06      30
# 9.44       30
# 9.8        30
# 13.98      30
# 15.38      30
# 23.79      30
# 11.08      30
# 26.21      30
# 26.2       30
# 16.72      30
# 20.84      30
# 11.81      30
# 21.31      30
# 13.34      30
# 19.85      30
# 18.82      30
# 23.55      30
# 26.07      30
# 15.08      30
# 25.64      30
# 23.0       30
# 15.18      30
# 23.6       30
# 11.85      30
# 17.74      30
# 17.51      30
# 12.17      30
# 19.33      30
# 26.47      30
# 18.06      30
# 19.01      30
# 23.03      30
# 11.88      30
# 11.22      30
# 7.79       30
# 25.84      30
# 24.22      30
# 13.26      30
# 12.85      30
# 25.69      30
# 28.23      30
# 27.16      30
# 26.35      30
# 17.02      30
# 22.7       30
# 9.36       29
# 28.02      29
# 26.64      29
# 12.86      29
# 19.14      29
# 13.09      29
# 23.36      29
# 21.41      29
# 9.57       29
# 13.53      29
# 17.53      29
# 9.92       29
# 23.51      29
# 11.59      29
# 8.93       29
# 19.23      29
# 14.23      29
# 16.04      29
# 24.26      29
# 28.88      29
# 10.52      29
# 19.74      29
# 10.16      29
# 25.61      29
# 20.49      29
# 21.98      29
# 18.35      29
# 10.56      29
# 19.02      29
# 8.44       29
# 7.2        29
# 24.18      29
# 21.87      29
# 28.32      29
# 10.45      29
# 8.23       29
# 15.03      29
# 10.62      29
# 24.64      29
# 24.51      29
# 14.72      29
# 10.1       29
# 16.64      29
# 22.06      29
# 13.86      29
# 18.77      29
# 23.63      29
# 10.51      29
# 12.19      29
# 28.5       29
# 29.46      29
# 20.91      29
# 8.37       29
# 16.67      29
# 10.63      29
# 25.54      29
# 23.78      29
# 23.17      29
# 14.47      29
# 13.1       29
# 17.66      29
# 9.34       29
# 23.1       29
# 24.92      29
# 16.5       29
# 15.15      29
# 23.23      29
# 19.94      29
# 15.41      29
# 22.24      29
# 28.58      29
# 11.21      29
# 26.86      29
# 20.87      29
# 27.36      29
# 25.0       29
# 20.42      29
# 25.62      29
# 23.61      29
# 22.54      29
# 22.13      29
# 22.47      29
# 13.16      29
# 28.01      29
# 9.31       29
# 22.89      29
# 24.59      29
# 27.18      29
# 14.24      29
# 24.17      29
# 10.92      29
# 15.91      29
# 26.15      29
# 17.55      29
# 14.56      29
# 25.07      29
# 18.95      29
# 21.63      29
# 24.07      29
# 16.85      29
# 24.61      29
# 24.28      29
# 19.29      29
# 14.19      28
# 9.66       28
# 6.0        28
# 10.57      28
# 28.0       28
# 11.44      28
# 15.63      28
# 22.33      28
# 11.67      28
# 22.9       28
# 11.53      28
# 12.26      28
# 24.93      28
# 19.18      28
# 22.23      28
# 26.36      28
# 31.38      28
# 11.98      28
# 19.75      28
# 11.61      28
# 20.52      28
# 25.1       28
# 12.83      28
# 20.93      28
# 16.33      28
# 27.2       28
# 16.95      28
# 24.12      28
# 24.75      28
# 17.12      28
# 25.86      28
# 28.16      28
# 25.26      28
# 13.37      28
# 19.99      28
# 27.28      28
# 25.7       28
# 14.58      28
# 11.15      28
# 23.9       28
# 27.54      28
# 18.16      28
# 11.63      28
# 20.32      28
# 23.16      28
# 29.38      28
# 18.36      28
# 21.4       28
# 26.3       28
# 28.29      28
# 22.14      28
# 29.68      28
# 29.66      28
# 16.63      28
# 25.46      28
# 26.27      28
# 13.46      28
# 28.7       28
# 21.28      28
# 19.28      28
# 11.05      28
# 14.07      28
# 24.38      28
# 9.96       28
# 23.18      28
# 15.82      28
# 10.76      28
# 21.93      28
# 12.95      28
# 23.26      28
# 15.51      28
# 20.14      28
# 11.78      28
# 13.36      28
# 13.79      28
# 11.41      28
# 17.72      28
# 19.41      28
# 21.29      28
# 12.76      28
# 26.5       28
# 10.95      28
# 16.91      28
# 10.73      28
# 9.74       28
# 18.22      28
# 23.42      28
# 20.27      28
# 10.07      28
# 9.68       28
# 13.43      28
# 23.53      28
# 24.73      28
# 12.55      28
# 9.06       28
# 26.54      28
# 13.06      28
# 28.9       28
# 10.26      28
# 19.86      28
# 10.67      28
# 11.56      28
# 24.1       27
# 10.78      27
# 28.83      27
# 10.69      27
# 17.82      27
# 10.7       27
# 11.35      27
# 24.25      27
# 15.16      26
# 31.44      26
# 24.11      26
# 18.7       26
# 24.77      26
# 14.39      26
# 29.73      26
# 8.86       26
# 27.06      26
# 23.21      26
# 26.98      26
# 22.45      26
# 10.05      26
# 24.43      26
# 21.49      26
# 19.06      26
# 26.29      26
# 8.22       26
# 25.29      26
# 21.91      26
# 22.42      26
# 23.27      26
# 12.4       26
# 24.19      26
# 27.24      26
# 31.16      26
# 19.54      26
# 10.08      26
# 23.41      26
# 11.0       26
# 11.49      26
# 25.93      26
# 22.73      26
# 17.48      26
# 23.01      26
# 9.89       26
# 22.31      26
# 12.82      26
# 26.69      26
# 19.53      26
# 29.22      26
# 9.17       26
# 19.81      26
# 12.23      25
# 22.83      25
# 26.56      25
# 26.79      25
# 27.72      25
# 24.94      25
# 9.7        25
# 16.17      25
# 9.91       25
# 25.4       25
# 29.59      25
# 23.13      25
# 9.94       25
# 12.74      25
# 26.73      25
# 25.74      25
# 20.9       25
# 12.13      25
# 15.54      25
# 25.48      25
# 13.76      25
# 23.5       25
# 12.07      25
# 10.82      25
# 13.35      25
# 27.8       25
# 24.05      25
# 14.43      25
# 9.11       25
# 20.89      25
# 28.68      25
# 14.14      25
# 25.95      25
# 23.57      25
# 12.22      25
# 24.39      25
# 28.47      25
# 19.12      25
# 24.42      25
# 16.94      25
# 18.58      25
# 10.88      25
# 24.46      25
# 8.97       25
# 23.39      25
# 11.9       25
# 25.9       25
# 24.57      25
# 8.6        25
# 29.61      25
# 10.27      25
# 25.66      25
# 27.87      25
# 28.77      25
# 25.71      25
# 16.14      25
# 28.3       25
# 25.76      25
# 8.45       25
# 14.08      25
# 21.43      25
# 25.82      25
# 11.27      25
# 19.97      25
# 26.99      25
# 30.32      25
# 13.49      25
# 29.25      25
# 18.54      25
# 7.23       25
# 7.32       25
# 26.61      25
# 7.88       25
# 10.98      25
# 21.42      25
# 7.18       25
# 9.81       25
# 25.16      25
# 23.29      25
# 8.24       25
# 10.55      25
# 12.35      25
# 8.35       25
# 9.32       25
# 15.8       25
# 21.52      25
# 25.51      25
# 6.36       25
# 24.99      25
# 16.19      25
# 6.99       25
# 20.65      25
# 31.96      25
# 26.06      25
# 7.5        25
# 24.31      25
# 15.29      25
# 8.71       25
# 14.68      25
# 17.13      25
# 28.84      25
# 23.43      25
# 30.8       25
# 27.74      25
# 18.05      25
# 26.76      25
# 30.42      25
# 18.42      25
# 8.43       25
# 21.05      25
# 7.41       25
# 14.65      25
# 11.83      25
# 7.72       25
# 21.82      25
# 24.41      25
# 8.59       24
# 10.15      24
# 23.05      24
# 25.14      24
# 27.48      24
# 29.96      24
# 30.64      24
# 22.07      24
# 17.21      24
# 30.34      24
# 26.34      24
# 8.77       24
# 25.34      24
# 20.53      24
# 7.31       24
# 31.78      24
# 21.34      24
# 28.96      24
# 5.79       24
# 27.92      24
# 33.88      24
# 29.44      24
# 11.18      24
# 30.81      24
# 11.26      24
# 15.83      24
# 20.99      24
# 32.4       24
# 28.71      24
# 20.01      24
# 23.74      24
# 29.28      24
# 27.81      24
# 25.85      24
# 17.79      22
# 30.53      22
# 8.52       22
# 29.17      22
# 10.83      22
# 9.05       22
# 7.29       22
# 30.92      22
# 30.31      22
# 27.6       22
# 26.71      22
# 12.75      22
# 31.52      22
# 6.45       22
# 9.2        22
# 22.55      22
# 23.47      22
# 6.82       22
# 27.85      22
# 23.24      22
# 28.69      22
# 27.78      22
# 28.05      22
# 25.72      22
# 9.04       22
# 28.92      22
# 29.36      22
# 27.01      22
# 33.75      22
# 9.52       22
# 28.63      22
# 28.14      22
# 9.1        22
# 21.35      22
# 4.94       22
# 28.28      22
# 26.45      22
# 27.33      22
# 14.41      22
# 21.44      22
# 4.8        22
# 33.99      22
# 30.5       22
# 29.78      22
# 34.24      22
# 10.84      22
# 10.68      22
# 11.29      22
# 30.24      22
# 28.42      22
# 9.39       22
# 7.55       22
# 10.41      22
# 28.55      22
# 10.93      22
# 13.95      22
# 28.49      22
# 29.06      22
# 27.94      22
# 28.1       22
# 30.88      22
# 24.3       22
# 18.59      22
# 10.89      22
# 8.95       22
# 6.09       22
# 31.58      22
# 32.24      22
# 29.14      22
# 24.83      22
# 26.11      22
# 27.89      22
# 8.69       22
# 9.59       22
# 32.1       22
# 10.66      22
# 8.74       22
# 27.99      22
# 30.05      22
# 6.73       22
# 20.7       22
# 23.84      22
# 33.6       22
# 27.39      22
# 10.19      22
# 27.65      22
# 22.44      22
# 9.09       22
# 9.83       22
# 9.0        22
# 28.82      22
# 20.39      22
# 32.79      22
# 9.99       22
# 21.46      22
# 27.47      22
# 23.54      22
# 11.54      21
# 6.6        21
# 14.15      21
# 32.85      21
# 19.15      21
# 10.25      21
# 25.91      21
# 31.57      21
# 29.93      21
# 22.92      21
# 7.46       21
# 11.6       21
# 9.35       21
# 27.15      21
# 12.2       21
# 14.79      21
# 27.9       21
# 5.8        21
# 21.19      21
# 31.24      21
# 7.78       21
# 9.15       21
# 31.06      21
# 5.64       21
# 28.26      21
# 26.08      21
# 8.17       21
# 23.71      21
# 11.2       21
# 29.77      21
# 29.74      21
# 5.08       21
# 32.2       21
# 6.22       21
# 29.07      21
# 9.98       21
# 32.18      21
# 28.59      21
# 22.49      21
# 12.91      21
# 18.25      21
# 8.15       21
# 9.49       21
# 34.12      21
# 20.17      21
# 29.32      21
# 24.54      21
# 29.94      21
# 25.45      21
# 27.58      21
# 24.68      21
# 19.19      21
# 28.37      21
# 11.16      21
# 7.1        21
# 12.68      21
# 22.64      21
# 27.53      21
# 24.82      21
# 25.87      21
# 20.69      21
# 12.41      21
# 9.67       21
# 25.31      21
# 6.89       21
# 26.12      21
# 28.34      21
# 34.07      21
# 8.25       21
# 9.19       21
# 25.43      21
# 7.85       21
# 32.22      21
# 22.41      21
# 30.39      21
# 29.87      21
# 11.77      21
# 7.45       21
# 16.69      21
# 8.04       21
# 8.54       21
# 24.97      21
# 33.07      21
# 6.11       21
# 25.58      21
# 24.49      21
# 30.63      21
# 25.01      21
# 27.05      21
# 25.35      21
# 10.5       21
# 20.34      21
# 24.86      21
# 18.01      21
# 27.25      21
# 28.35      21
# 31.63      21
# 10.03      21
# 31.76      21
# 9.29       21
# 29.11      21
# 29.63      21
# 26.77      21
# 29.33      21
# 15.27      21
# 34.93      21
# 23.08      20
# 28.33      20
# 28.56      20
# 7.81       20
# 31.14      20
# 29.27      20
# 29.09      20
# 9.76       20
# 9.86       20
# 28.89      20
# 28.76      20
# 33.97      20
# 6.92       20
# 26.1       20
# 7.96       20
# 7.65       20
# 6.13       20
# 26.23      20
# 8.27       20
# 8.11       20
# 6.66       20
# 32.8       20
# 34.29      20
# 11.75      20
# 24.58      20
# 8.08       20
# 6.12       20
# 31.7       20
# 27.75      20
# 10.48      20
# 34.4       20
# 19.7       20
# 27.76      20
# 5.25       20
# 33.25      20
# 32.33      20
# 31.88      20
# 9.25       20
# 8.92       20
# 20.86      20
# 16.01      20
# 7.07       20
# 6.93       20
# 30.08      20
# 29.05      20
# 25.65      20
# 7.84       20
# 27.3       20
# 12.47      20
# 5.09       20
# 5.94       20
# 29.89      20
# 29.49      20
# 32.03      20
# 10.23      20
# 21.37      20
# 29.75      20
# 26.32      20
# 22.79      20
# 34.06      20
# 7.71       20
# 7.94       20
# 6.24       20
# 7.82       20
# 26.93      20
# 27.68      20
# 28.94      20
# 9.55       20
# 6.57       20
# 28.41      20
# 23.48      20
# 29.41      20
# 6.35       20
# 28.95      20
# 30.7       20
# 30.83      20
# 30.74      20
# 8.03       20
# 32.0       20
# 8.14       20
# 25.21      20
# 28.97      20
# 34.85      20
# 29.02      20
# 7.93       20
# 31.65      20
# 34.8       20
# 15.5       20
# 31.81      20
# 28.19      20
# 33.09      20
# 25.3       20
# 29.16      20
# 26.65      20
# 7.76       20
# 8.79       20
# 30.57      20
# 6.28       20
# 32.37      20
# 6.04       20
# 7.16       20
# 28.06      20
# 7.39       20
# 29.29      20
# 26.57      20
# 7.52       20
# 9.3        20
# 7.44       20
# 34.67      20
# 12.49      20
# 8.42       20
# 8.66       20
# 20.78      19
# 8.68       19
# 5.28       19
# 31.02      19
# 32.23      19
# 32.13      19
# 23.37      19
# 6.31       19
# 31.5       19
# 32.28      19
# 33.39      19
# 16.79      19
# 9.93       19
# 27.79      19
# 10.58      19
# 28.51      19
# 32.15      19
# 33.81      19
# 6.81       19
# 28.07      19
# 29.8       19
# 9.02       19
# 24.95      19
# 30.29      19
# 34.1       19
# 7.7        19
# 24.67      19
# 9.22       19
# 6.48       19
# 26.42      19
# 27.91      19
# 9.63       19
# 10.33      19
# 34.64      19
# 26.26      19
# 33.49      19
# 6.26       19
# 9.62       19
# 8.06       19
# 29.47      19
# 29.62      19
# 32.05      19
# 29.98      19
# 26.41      19
# 8.07       19
# 11.09      19
# 30.91      19
# 7.03       19
# 6.95       19
# 23.81      19
# 6.72       19
# 8.89       19
# 33.65      19
# 5.81       19
# 5.86       19
# 15.13      19
# 27.97      19
# 29.12      19
# 29.9       19
# 9.08       19
# 29.56      19
# 32.38      19
# 30.16      19
# 28.45      19
# 8.94       19
# 9.79       19
# 25.12      19
# 29.0       19
# 26.95      19
# 8.91       19
# 27.73      19
# 28.38      19
# 32.16      19
# 6.47       13
# 31.86      13
# 33.16      13
# 6.44       13
# 6.51       13
# 3.76       13
# 34.99      13
# 2.31       13
# 3.41       13
# 34.32      13
# 33.32      13
# 6.2        13
# 7.22       13
# 33.69      13
# 34.45      13
# 3.64       13
# 35.52      13
# 30.19      13
# 33.28      13
# 30.55      13
# 5.23       13
# 34.75      13
# 34.09      13
# 32.99      13
# 29.21      13
# 7.0        13
# 33.98      13
# 34.5       13
# 28.81      13
# 1.5        13
# 5.7        13
# 5.11       13
# 36.1       13
# 6.63       13
# 5.02       13
# 32.89      13
# 31.17      13
# 32.56      13
# 30.38      13
# 2.21       13
# 5.31       13
# 30.77      13
# 4.68       13
# 6.43       13
# 33.45      13
# 30.99      13
# 32.7       13
# 31.56      13
# 32.09      13
# 31.3       13
# 33.46      13
# 31.26      13
# 1.65       13
# 31.21      13
# 10.61      13
# 34.19      13
# 30.14      13
# 33.22      13
# 32.91      13
# 6.02       13
# 13.47      13
# 36.42      13
# 34.37      13
# 36.24      13
# 32.48      13
# 33.3       13
# 34.97      13
# 34.47      13
# 37.44      13
# 33.85      13
# 34.04      13
# 33.63      13
# 3.23       13
# 27.11      13
# 31.89      13
# 37.33      12
# 3.74       12
# 30.66      12
# 7.28       12
# 29.99      12
# 34.94      12
# 34.78      12
# 30.21      12
# 34.28      12
# 5.51       12
# 35.15      12
# 5.21       12
# 30.94      12
# 3.85       12
# 32.21      12
# 5.3        12
# 37.2       12
# 7.48       12
# 32.44      12
# 34.86      12
# 32.61      12
# 33.94      12
# 33.76      12
# 5.5        12
# 37.6       12
# 30.28      12
# 3.11       12
# 32.76      12
# 34.57      12
# 31.95      12
# 31.64      12
# 6.55       12
# 34.27      12
# 4.7        12
# 34.82      12
# 29.42      12
# 5.92       12
# 5.54       12
# 6.74       12
# 37.17      12
# 34.7       12
# 3.75       12
# 32.75      12
# 34.41      12
# 30.97      12
# 4.56       12
# 36.6       12
# 8.39       12
# 37.23      12
# 35.74      12
# 35.36      12
# 6.15       12
# 35.56      12
# 35.88      12
# 34.05      12
# 3.07       12
# 7.13       12
# 3.65       12
# 32.32      12
# 35.96      12
# 6.27       12
# 32.93      12
# 28.17      12
# 31.98      12
# 36.52      12
# 32.86      12
# 34.23      12
# 6.39       12
# 3.06       12
# 27.59      12
# 29.58      12
# 1.8        12
# 3.33       12
# 6.59       12
# 39.03      12
# 36.0       12
# 34.89      12
# 6.62       12
# 5.07       12
# 32.19      12
# 34.76      12
# 6.46       12
# 5.1        12
# 33.66      12
# 30.86      12
# 4.6        12
# 28.18      12
# 37.38      12
# 33.61      12
# 33.18      12
# 33.93      12
# 33.79      12
# 2.07       12
# 37.05      12
# 4.67       11
# 32.49      11
# 32.35      11
# 36.49      11
# 36.3       11
# 37.64      11
# 31.61      11
# 3.54       11
# 3.68       11
# 4.1        11
# 36.12      11
# 38.28      11
# 3.87       11
# 38.86      11
# 37.95      11
# 34.62      11
# 37.32      11
# 4.01       11
# 10.09      11
# 31.75      11
# 32.74      11
# 2.5        11
# 38.53      11
# 35.46      11
# 30.79      11
# 5.88       11
# 34.17      11
# 3.14       11
# 36.77      11
# 3.17       11
# 5.37       11
# 7.49       11
# 30.17      11
# 34.55      11
# 2.57       11
# 5.34       11
# 4.28       11
# 4.66       11
# 5.99       11
# 33.62      11
# 31.12      11
# 35.76      11
# 32.14      11
# 4.99       11
# 4.13       11
# 2.54       11
# 3.7        11
# 36.48      11
# 34.38      11
# 6.61       11
# 36.46      11
# 37.3       11
# 35.38      11
# 30.58      11
# 2.97       11
# 4.64       11
# 3.43       11
# 3.94       11
# 1.86       11
# 34.51      11
# 7.73       11
# 35.06      11
# 32.51      11
# 33.56      11
# 35.8       11
# 2.28       11
# 36.93      11
# 5.01       11
# 4.73       11
# 26.24      11
# 4.78       11
# 2.24       11
# 35.13      11
# 3.29       11
# 4.47       11
# 34.9       11
# 33.55      11
# 35.91      11
# 33.27      11
# 37.0       11
# 4.34       11
# 3.01       11
# 4.63       11
# 36.99      11
# 37.89      11
# 35.51      11
# 30.41      11
# 31.99      11
# 32.5       11
# 3.82       11
# 2.79       11
# 4.43       11
# 34.25      11
# 34.52      11
# 35.19      11
# 6.33       11
# 35.32      11
# 2.96       11
# 37.21      11
# 35.81      11
# 6.7        11
# 31.94      11
# 7.19       10
# 1.0        10
# 4.37       10
# 34.73      10
# 31.77      10
# 32.11      10
# 5.57       10
# 4.69       10
# 36.83      10
# 33.43      10
# 2.68       10
# 31.03      10
# 31.15      10
# 36.35      10
# 38.47      10
# 4.85       10
# 4.57       10
# 33.19      10
# 6.71       10
# 5.58       10
# 5.45       10
# 35.03      10
# 3.2        10
# 7.63       10
# 39.2       10
# 34.66      10
# 3.21       10
# 35.94      10
# 36.39      10
# 38.84      10
# 36.17      10
# 19.21      10
# 31.1       10
# 33.34      10
# 4.21       10
# 38.37      10
# 35.34      10
# 6.41       10
# 3.36       10
# 36.06      10
# 2.59       10
# 1.51       10
# 5.32       10
# 36.64      10
# 38.22      10
# 36.91      10
# 35.53      10
# 32.62      10
# 38.72      10
# 35.71      10
# 37.06      10
# 37.55      10
# 4.22       10
# 1.92       10
# 35.18      10
# 3.34       10
# 2.67       10
# 34.98      10
# ...
# 37.48       9
# 5.87        9
# 38.08       9
# 38.48       9
# 33.77       9
# 7.17        9
# 35.9        9
# 3.52        9
# 38.02       9
# 34.59       9
# 4.48        9
# 4.58        9
# 36.62       9
# 37.31       9
# 4.91        9
# 37.65       9
# 39.92       9
# 31.67       9
# 3.71        9
# 3.81        9
# 37.92       9
# 36.15       9
# 38.88       9
# 1.3         9
# 3.15        9
# 2.61        8
# 36.97       8
# 37.75       8
# 35.61       8
# 4.98        8
# 36.65       8
# 2.92        8
# 36.28       8
# 34.44       8
# 1.26        8
# 37.03       8
# 4.46        8
# 0.59        8
# 2.88        8
# 2.44        8
# 35.55       8
# 3.42        8
# 4.96        8
# 35.57       8
# 37.19       8
# 35.02       8
# 35.07       8
# 2.87        8
# 35.26       8
# 36.25       8
# 37.81       8
# 38.92       8
# 4.24        8
# 4.44        8
# 2.06        8
# 36.78       8
# 38.59       8
# 33.67       8
# 33.7        8
# 39.52       8
# 38.98       8
# 3.08        8
# 2.81        8
# 37.22       8
# 36.34       8
# 35.29       8
# 38.19       8
# 36.58       8
# 38.63       8
# 31.59       8
# 3.27        8
# 4.26        8
# 31.39       8
# 38.5        8
# 4.52        8
# 3.13        8
# 35.65       8
# 39.32       8
# 38.11       8
# 31.08       8
# 4.55        8
# 5.53        8
# 2.63        8
# 33.82       8
# 37.41       8
# 4.0         8
# 2.01        8
# 2.73        8
# 36.67       8
# 4.11        8
# 36.69       8
# 36.4        8
# 3.55        8
# 3.78        8
# 35.0        8
# 3.89        8
# 7.21        8
# 36.45       8
# 35.16       8
# 3.98        8
# 37.47       8
# 39.49       8
# 36.54       8
# 37.93       8
# 37.79       8
# 39.6        8
# 3.31        8
# 2.7         8
# 3.19        8
# 5.22        8
# 37.49       8
# 3.22        8
# 36.03       8
# 4.95        8
# 35.84       8
# 37.85       8
# 39.66       8
# 38.46       8
# 1.76        8
# 3.25        8
# 35.95       8
# 5.29        8
# 6.42        8
# 3.95        8
# 39.73       8
# 2.58        8
# 38.89       8
# 36.05       8
# 2.0         8
# 1.41        8
# 2.69        8
# 4.17        8
# 31.19       8
# 1.95        8
# 38.74       8
# 35.87       8
# 33.04       8
# 1.47        8
# 36.07       8
# 3.92        8
# 3.8         8
# 39.22       8
# 37.66       8
# 38.25       7
# 35.86       7
# 36.81       7
# 4.31        7
# 34.3        7
# 37.27       7
# 39.12       7
# 1.85        7
# 37.04       7
# 34.54       7
# 39.78       7
# 4.81        7
# 2.26        7
# 39.39       7
# 2.19        7
# 2.95        7
# 35.14       7
# 33.68       7
# 39.88       7
# 4.62        7
# 35.77       7
# 36.56       7
# 3.24        7
# 36.68       7
# 38.49       7
# 3.39        7
# 1.9         7
# 2.09        7
# 38.78       7
# 37.78       7
# 38.97       7
# 2.62        7
# 36.44       7
# 3.57        7
# 38.01       7
# 4.03        7
# 38.16       7
# 39.86       7
# 1.32        7
# 2.12        7
# 1.94        7
# 36.73       7
# 35.59       7
# 1.56        7
# 3.03        7
# 1.7         7
# 36.55       7
# 1.88        7
# 39.18       7
# 35.98       7
# 2.47        7
# 36.74       7
# 36.14       7
# 37.45       7
# 35.01       7
# 37.1        7
# 4.84        7
# 37.53       7
# 38.45       7
# 38.3        7
# 35.7        7
# 35.75       7
# 2.8         7
# 37.09       7
# 1.68        7
# 35.78       7
# 1.69        7
# 0.6         7
# 36.75       7
# 3.28        7
# 2.49        7
# 3.48        7
# 34.61       7
# 3.26        7
# 38.14       7
# 35.83       7
# 0.55        7
# 2.64        7
# 36.13       7
# 3.44        7
# 34.39       7
# 1.45        7
# 2.23        7
# 35.39       7
# 5.18        7
# 37.87       7
# 39.05       7
# 37.96       7
# 38.62       7
# 4.15        7
# 39.75       7
# 36.02       7
# 39.0        7
# 36.89       7
# 37.26       7
# 37.63       7
# 3.73        7
# 32.41       7
# 35.4        7
# 35.09       7
# 0.94        7
# 36.11       7
# 3.37        7
# 3.1         7
# 38.69       7
# 3.58        7
# 38.43       7
# 38.95       7
# 31.87       7
# 2.02        7
# 34.22       7
# 2.34        7
# 35.12       7
# 38.36       7
# 2.77        7
# 33.11       7
# 3.4         7
# 2.42        7
# 5.05        7
# 36.36       7
# 1.15        7
# 36.04       7
# 35.63       7
# 1.52        7
# 35.58       7
# 35.68       7
# 0.84        7
# 39.35       7
# 1.87        6
# 5.2         6
# 2.33        6
# 2.52        6
# 1.82        6
# 37.15       6
# 2.15        6
# 37.52       6
# 3.02        6
# 2.11        6
# 39.83       6
# 2.76        6
# 38.76       6
# 0.77        6
# 38.0        6
# 1.66        6
# 38.71       6
# 38.07       6
# 3.88        6
# 4.45        6
# 38.24       6
# 3.16        6
# 3.47        6
# 25.19       6
# 38.83       6
# 39.11       6
# 35.45       6
# 33.59       6
# 2.66        6
# 2.6         6
# 37.13       6
# 2.25        6
# 34.74       6
# 2.05        6
# 3.63        6
# 36.16       6
# 4.04        6
# 2.14        6
# 35.1        6
# 38.57       6
# 2.75        6
# 1.31        6
# 2.1         6
# 37.94       6
# 38.26       6
# 38.77       6
# 36.27       6
# 36.51       6
# 3.04        6
# 2.74        6
# 38.31       6
# 39.31       6
# 4.79        6
# 36.86       6
# 1.23        6
# 36.31       6
# 2.53        6
# 1.27        6
# 36.96       6
# 39.55       6
# 3.51        6
# 1.6         6
# 39.43       6
# 35.79       6
# 39.81       6
# 3.99        6
# 37.51       6
# 37.18       6
# 37.42       6
# 3.9         6
# 39.24       6
# 0.3         6
# 35.47       6
# 35.64       6
# 39.41       6
# 38.91       6
# 5.68        6
# 38.96       6
# 32.39       6
# 39.08       6
# 36.26       6
# 35.11       6
# 4.02        6
# 39.5        6
# 34.87       6
# 6.9         6
# 37.35       6
# 39.45       6
# 36.41       6
# 0.37        6
# 36.87       6
# 32.01       6
# 36.95       6
# 1.55        6
# 36.33       6
# 37.08       6
# 3.38        6
# 37.99       6
# 33.8        6
# 36.82       6
# 32.81       6
# 37.25       6
# 35.17       6
# 1.09        6
# 36.85       6
# 35.24       6
# 35.49       6
# 35.27       6
# 38.12       6
# 4.92        6
# 36.71       5
# 3.09        5
# 3.45        5
# 39.28       5
# 2.29        5
# 37.07       5
# 38.73       5
# 38.56       5
# 38.58       5
# 3.69        5
# 38.06       5
# 39.36       5
# 3.62        5
# 36.84       5
# 2.94        5
# 5.85        5
# 37.71       5
# 38.64       5
# 38.39       5
# 39.42       5
# 37.39       5
# 1.12        5
# 38.7        5
# 38.52       5
# 0.99        5
# 38.04       5
# 36.01       5
# 37.88       5
# 2.32        5
# 36.09       5
# 37.12       5
# 1.81        5
# 38.82       5
# 38.61       5
# 4.65        5
# 2.36        5
# 37.46       5
# 37.91       5
# 39.8        5
# 0.58        5
# 5.27        5
# 3.56        5
# 35.92       5
# 37.58       5
# 39.15       5
# 38.9        5
# 36.38       5
# 38.29       5
# 38.2        5
# 35.67       5
# 0.86        5
# 4.19        5
# 4.54        5
# 37.97       5
# 0.72        5
# 39.61       5
# 36.7        5
# 34.72       5
# 36.79       5
# 0.45        5
# 1.78        5
# 3.61        5
# 3.79        5
# 2.84        5
# 1.91        5
# 185.88      1
# 48.75       1
# 365.17      1
# 38.93       1
# 46.75       1
# 96.28       1
# 78.31       1
# 108.71      1
# 42.39       1
# 54.73       1
# 45.97       1
# 73.54       1
# 42.06       1
# 0.97        1
# 58.4        1
# 56.76       1
# 40.92       1
# 82.82       1
# 1.49        1
# 70.89       1
# 43.16       1
# 63.74       1
# 44.03       1
# 42.42       1
# 41.95       1
# 50.96       1
# 131.0       1
# 59.77       1
# 81.35       1
# 81.47       1
# 751.22      1
# 39.72       1
# 60.03       1
# 43.06       1
# 69.47       1
# 42.83       1
# 42.88       1
# 70.9        1
# 46.45       1
# 51.52       1
# 38.66       1
# 40.31       1
# 40.45       1
# 48.67       1
# 49.14       1
# 0.17        1
# 0.46        1
# 47.33       1
# 43.58       1
# 46.98       1
# 50.95       1
# 65.2        1
# 47.59       1
# 45.77       1
# 42.57       1
# 41.81       1
# 44.33       1
# 0.89        1
# 41.49       1
# 50.04       1
# 44.02       1
# 44.86       1
# 42.98       1
# 0.64        1
# 71.96       1
# 61.27       1
# 50.8        1
# 43.78       1
# 62.63       1
# 64.17       1
# 47.71       1
# 49.4        1
# 57.36       1
# 66.6        1
# 0.42        1
# 75.2        1
# 51.69       1
# 69.52       1
# 65.61       1
# 55.51       1
# 81.75       1
# 82.59       1
# 48.42       1
# 41.79       1
# 0.28        1
# 83.94       1
# 47.04       1
# 46.05       1
# 50.41       1
# 108.14      1
# 46.92       1
# 69.76       1
# 66.53       1
# 46.46       1
# 57.68       1
# 40.22       1
# 0.2         1
# 59.45       1
# 48.37       1
# 44.99       1
# 53.72       1
# 55.62       1
# 115.0       1
# 40.47       1
# 52.47       1
# 64.67       1
# 78.09       1
# 67.14       1
# 42.77       1
# 44.79       1
# 228.33      1
# 42.32       1
# 47.46       1
# Name: count, dtype: int64

# %% [markdown]
# ## 2A.5 Cleaning Based on Diagnostics for Categorical Variables
#
# The categorical diagnostics revealed several structural inconsistencies, duplicated categories, formatting issues, and variables requiring datatype correction.
# This section documents the cleaning steps applied to ensure all categorical fields are standardized, interpretable, and ready for modeling.
#
# ---
#
# ### 1. Remove `_text` suffix from categorical variables
#
# Some categorical variables were originally stored with a `_text` suffix.
# These were renamed to cleaner, modeling‑friendly versions:
#
# - `repayment_term_text` → `repayment_term`
# - `employment_tenure_text` → `employment_tenure`
#
# Only the name was changed — the underlying dtype remains as string/object.
#
# ---
#
# ### 2. Remove redundant categorical variable
#
# `risk_grade_band` and `risk_grade_detail` encode the same information at different granularities.
# To avoid multicollinearity and redundancy:
#
# - **`risk_grade_band` was removed**
# - **`risk_grade_detail` was retained** as the more detailed and informative variable
#
# ---
#
# ### 3. Standardize formatting across all categorical variables
#
# Many categorical fields contained inconsistent capitalization, spacing, or duplicated categories.
# To ensure uniformity, the following transformations were applied:
#
# - Trim leading/trailing spaces
# - Convert all text to lowercase
# - Normalize inconsistent variants (e.g., `MORTGAGE`, `mortgage`, `Mortgage` → `mortgage`)
#
# This standardization was applied to:
#
# - `repayment_term`
# - `employment_tenure`
# - `housing_status`
# - `income_verification_status`
# - `origination_month`
# - `outcome_status`
# - `loan_purpose`
# - `region_code`
#
# ---
#
# ### 4. Consolidate and correct specific categorical fields
#
# #### **Housing status**
# The diagnostics showed duplicated categories due to inconsistent capitalization.
# All values were standardized to:
#
# - `mortgage`
# - `rent`
# - `own`
# - `any` (rare category)
#
# #### **Income verification status**
# Two categories represented the same meaning:
#
# - `source verified`
# - `verified`
#
# These were merged into a single category:
#
# - **`verified`**
#
# #### **Loan purpose**
# Duplicate categories existed due to inconsistent casing (e.g., `debt_consolidation` appearing twice).
# All values were standardized to lowercase and deduplicated.
#
# #### **Region code**
# State codes appeared in both uppercase and lowercase.
# All values were converted to lowercase for consistency.
#
# ---
#
# ### 5. Convert `origination_month` to datetime
#
# `origination_month` was stored as a text label (e.g., `"Jul-2015"`).
# To enable time‑based feature engineering, it was converted to a proper datetime format:
#
# - `"Jul-2015"` → `2015-07-01`
# - `"Oct-2015"` → `2015-10-01`
# - etc.
#
# Invalid or unparseable values were set to `NaT`.
#
# ---
#
# ### 6. Clean and convert `debt_to_income_ratio` to numeric
#
# Diagnostics revealed that this variable contained:
#
# - numeric strings (`"18.0"`, `"24.0"`)
# - corrupted values (`"bad"`)
# - missing values (`NaN`)
#
# To correct this:
#
# - `"bad"` was replaced with `NaN`
# - the column was converted to numeric using `pd.to_numeric(errors='coerce')`
#
# This ensures the variable is ready for imputation and modeling.
#
# ---
#
# ### 7. Final categorical dataset status
#
# After applying all cleaning steps:
#
# - All categorical variables are standardized, lowercase, and stripped of whitespace
# - Redundant variables have been removed
# - Datatypes are consistent across the dataset
# - `origination_month` is now a datetime variable
# - `debt_to_income_ratio` is now numeric

# %%
# -----------------------------
# 1. Remove _text suffix for categorical variables
# -----------------------------

apps.rename(columns={
    'repayment_term_text': 'repayment_term',
    'employment_tenure_text': 'employment_tenure'
}, inplace=True)

# -----------------------------
# 2. Drop redundant categorical variable
# risk_grade_band gives same info as risk_grade_detail
# -----------------------------

apps.drop(columns=['risk_grade_band'], inplace=True)

# -----------------------------
# 3. Standardize categorical variables (strip + lowercase)
# -----------------------------

cat_cols_to_clean = [
    'repayment_term',
    'employment_tenure',
    'housing_status',
    'income_verification_status',
    'origination_month',
    'outcome_status',
    'loan_purpose',
    'region_code'
]

for col in cat_cols_to_clean:
    apps[col] = apps[col].astype('string').str.strip().str.lower()

# -----------------------------
# 4. Fix housing_status duplicates (mortgage vs MORTGAGE, etc.)
# -----------------------------

apps['housing_status'] = apps['housing_status'].replace({
    'mortgage': 'mortgage',
    'rent': 'rent',
    'own': 'own'
})

# -----------------------------
# 5. Fix income_verification_status
# merge "source verified" + "verified" → "verified"
# -----------------------------

apps['income_verification_status'] = apps['income_verification_status'].replace({
    'source verified': 'verified',
    'verified': 'verified'
})

# -----------------------------
# 6. Convert origination_month to datetime
# -----------------------------

apps['origination_month'] = pd.to_datetime(apps['origination_month'], format='%b-%Y', errors='coerce')

# -----------------------------
# 7. Clean debt_to_income_ratio
# replace "bad" with NaN and convert to numeric
# -----------------------------

apps['debt_to_income_ratio'] = apps['debt_to_income_ratio'].replace('bad', pd.NA)
apps['debt_to_income_ratio'] = pd.to_numeric(apps['debt_to_income_ratio'], errors='coerce')

# %%
apps.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 85000 entries, 0 to 84999
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   requested_amount_usd        85000 non-null  float64
#  1   repayment_term              85000 non-null  string
#  2   monthly_installment_usd     85000 non-null  float64
#  3   last_payment_amount_usd     85000 non-null  float64
#  4   risk_grade_detail           85000 non-null  str
#  5   employment_tenure           76324 non-null  string
#  6   housing_status              85000 non-null  string
#  7   annual_income_usd           84320 non-null  float64
#  8   income_verification_status  85000 non-null  string
#  9   origination_month           85000 non-null  datetime64[us]
#  10  outcome_status              85000 non-null  string
#  11  loan_purpose                85000 non-null  string
#  12  region_code                 85000 non-null  string
#  13  debt_to_income_ratio        83955 non-null  float64
#  14  credit_score_low            85000 non-null  float64
#  15  credit_score_high           85000 non-null  float64
#  16  open_credit_lines           85000 non-null  float64
#  17  public_records_count        85000 non-null  float64
#  18  interest_rate               85000 non-null  float64
#  19  revolving_utilization       84108 non-null  float64
# dtypes: datetime64[us](1), float64(11), str(1), string(7)
# memory usage: 13.0 MB

# %%
apps.select_dtypes(include=['object', 'string']).describe()
# Out:
#        repayment_term risk_grade_detail employment_tenure housing_status  \
# count           85000             85000             76324          85000
# unique              2                35                11              4
# top         36 months                C4         10+ years       mortgage
# freq            59223              5289             26275          39118
#
#        income_verification_status outcome_status        loan_purpose  \
# count                       85000          85000               85000
# unique                          2              2                  12
# top                      verified     fully paid  debt_consolidation
# freq                        63539          42500               50891
#
#        region_code
# count        85000
# unique          50
# top             ca
# freq         11842

# %%
apps.select_dtypes(include=['int64', 'float64']).describe()
# Out:
#        requested_amount_usd  monthly_installment_usd  last_payment_amount_usd  \
# count          85000.000000             85000.000000             85000.000000
# mean           14950.852647               446.071413              3604.090989
# std             8735.147461               258.523612              6222.901104
# min             1000.000000                30.120000                 0.000000
# 25%             8000.000000               259.955000               308.220000
# 50%            13050.000000               382.870000               598.895000
# 75%            20000.000000               587.690000              4130.377500
# max            40000.000000              1587.230000             40551.270000
#
#        annual_income_usd  debt_to_income_ratio  credit_score_low  \
# count       8.432000e+04          83955.000000      85000.000000
# mean        7.434189e+04             19.682500        692.034412
# std         7.732271e+04             13.170892         29.787475
# min         0.000000e+00              0.000000        660.000000
# 25%         4.500000e+04             12.800000        670.000000
# 50%         6.300000e+04             18.990000        685.000000
# 75%         9.000000e+04             25.910000        705.000000
# max         8.900060e+06            999.000000        845.000000
#
#        credit_score_high  open_credit_lines  public_records_count  \
# count       85000.000000       85000.000000          85000.000000
# mean          696.034482          11.920871              0.248718
# std            29.787839           5.670095              0.656437
# min           664.000000           1.000000              0.000000
# 25%           674.000000           8.000000              0.000000
# 50%           689.000000          11.000000              0.000000
# 75%           709.000000          15.000000              0.000000
# max           850.000000          70.000000             49.000000
#
#        interest_rate  revolving_utilization
# count   85000.000000           84108.000000
# mean       13.600630              52.342891
# std         4.886372              24.293508
# min         5.310000               0.000000
# 25%         9.990000              34.200000
# 50%        13.180000              52.800000
# 75%        16.550000              70.900000
# max        30.990000             136.400000
